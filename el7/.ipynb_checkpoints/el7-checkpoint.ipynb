# %% [markdown]
# # Ejercicio 7 de laboratorio

# %%
from ucimlrepo import fetch_ucirepo
from random import randint
from random import shuffle
import pandas as pd
import numpy as np

# %%
adult = fetch_ucirepo(id=2)

# %%
iris = fetch_ucirepo(id=53)

# %%
wine_quality = fetch_ucirepo(id=186)

# %%
abalone = fetch_ucirepo(id=1)

# %%
abalone.data.features = abalone.data.features.replace('M', 0)
abalone.data.features = abalone.data.features.replace('F', 1)
abalone.data.features = abalone.data.features.replace('I', 2)
abalone.data.features
# Out:
# /tmp/ipykernel_737930/3652355604.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   abalone.data.features = abalone.data.features.replace('I', 2)
#       Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0       0   0.455     0.365   0.095        0.5140          0.2245
# 1       0   0.350     0.265   0.090        0.2255          0.0995
# 2       1   0.530     0.420   0.135        0.6770          0.2565
# 3       0   0.440     0.365   0.125        0.5160          0.2155
# 4       2   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    1   0.565     0.450   0.165        0.8870          0.3700
# 4173    0   0.590     0.440   0.135        0.9660          0.4390
# 4174    0   0.600     0.475   0.205        1.1760          0.5255
# 4175    1   0.625     0.485   0.150        1.0945          0.5310
# 4176    0   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight
# 0             0.1010        0.1500
# 1             0.0485        0.0700
# 2             0.1415        0.2100
# 3             0.1140        0.1550
# 4             0.0395        0.0550
# ...              ...           ...
# 4172          0.2390        0.2490
# 4173          0.2145        0.2605
# 4174          0.2875        0.3080
# 4175          0.2610        0.2960
# 4176          0.3765        0.4950
#
# [4177 rows x 8 columns]

# %%
X = iris.data.features 
Y = iris.data.targets

# %%
union = pd.concat([X,Y],axis=1)
union2 = pd.concat([wine_quality.data.features,wine_quality.data.targets],axis=1)
union3 = pd.concat([abalone.data.features,abalone.data.targets],axis=1)
union2.iloc[0]
union3
# Out:
#       Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0       0   0.455     0.365   0.095        0.5140          0.2245
# 1       0   0.350     0.265   0.090        0.2255          0.0995
# 2       1   0.530     0.420   0.135        0.6770          0.2565
# 3       0   0.440     0.365   0.125        0.5160          0.2155
# 4       2   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    1   0.565     0.450   0.165        0.8870          0.3700
# 4173    0   0.590     0.440   0.135        0.9660          0.4390
# 4174    0   0.600     0.475   0.205        1.1760          0.5255
# 4175    1   0.625     0.485   0.150        1.0945          0.5310
# 4176    0   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %% [markdown]
# ## Hold out

# %% [markdown]
# El hold out specifica que porcentaje del dataset se va a dejar afuera para validación/testing. en este caso un r, donde r pertenece a [0,1]

# %%
def holdOut(li, r): # Recibe un listado iterable que contenga los filas o instancias
    # Logra separar en classes discretas
    l = li.drop_duplicates(ignore_index=True)
    tam = len(l.index)
    elems = list(range(tam))
    clases = {}
    for a in range(tam):
        # print(l.iat[a, -1])  # Se asume que la clase esta en la ultima columna
        c = l.iat[a,-1]
        if c not in clases:
            clases[c] = []
        else:
            clases[c].append(a)
    ent = []
    val = []
    for k in clases:
        t = len(clases[k])
        v = int(t*r)
        shuffle(clases[k])
        val += clases[k][0:v]
        ent += clases[k][v:]
    return l.iloc[ent],l.iloc[val]

ent,val = holdOut(union, 0.3)

# %%
ent2,val2 = holdOut(union2,0.3)

# %%
def elemComun(a, b): # a y b son datasets de pandas, retorna true si existen elementos en comun
    tamA = len(a.index)
    tamB = len(b.index)
    df3 = pd.concat([a,b], ignore_index=True)
    df3 = df3.drop_duplicates(ignore_index=True)
    tamRes = len(df3.index)
    print(tamA,tamB,tamRes)
    if((tamA + tamB) > tamRes):
        return True # Existen elementos en comun
    else:
        return False # No existen elementos en comun

# %%
print(elemComun(ent,val)) # Observamos si la separacion causo elementos repetidos
print(elemComun(ent2,val2))
print(elemComun(ent,ent))
# Out:
# 102 42 144
# False
# 3720 1591 5311
# False
# 102 102 102
# True

# %%
print(ent)
print(val)
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 19            5.1          3.8           1.5          0.3     Iris-setosa
# 39            4.5          2.3           1.3          0.3     Iris-setosa
# 16            5.4          3.9           1.3          0.4     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 30            4.8          3.1           1.6          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 115           7.7          3.8           6.7          2.2  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
# 131           6.3          2.8           5.1          1.5  Iris-virginica
# 116           7.7          2.6           6.9          2.3  Iris-virginica
# 133           7.7          3.0           6.1          2.3  Iris-virginica
#
# [102 rows x 5 columns]
#      sepal length  sepal width  petal length  petal width            class
# 13            4.3          3.0           1.1          0.1      Iris-setosa
# 3             4.6          3.1           1.5          0.2      Iris-setosa
# 47            5.0          3.3           1.4          0.2      Iris-setosa
# 15            5.7          4.4           1.5          0.4      Iris-setosa
# 10            5.4          3.7           1.5          0.2      Iris-setosa
# 18            5.7          3.8           1.7          0.3      Iris-setosa
# 4             5.0          3.6           1.4          0.2      Iris-setosa
# 38            5.0          3.5           1.3          0.3      Iris-setosa
# 33            5.5          4.2           1.4          0.2      Iris-setosa
# 37            5.1          3.4           1.5          0.2      Iris-setosa
# 21            5.1          3.7           1.5          0.4      Iris-setosa
# 43            4.8          3.0           1.4          0.3      Iris-setosa
# 9             4.9          3.1           1.5          0.1      Iris-setosa
# 42            5.1          3.8           1.9          0.4      Iris-setosa
# 83            6.0          3.4           4.5          1.6  Iris-versicolor
# 96            5.1          2.5           3.0          1.1  Iris-versicolor
# 70            6.3          2.5           4.9          1.5  Iris-versicolor
# 65            5.8          2.7           4.1          1.0  Iris-versicolor
# 51            5.5          2.3           4.0          1.3  Iris-versicolor
# 62            5.6          2.9           3.6          1.3  Iris-versicolor
# 75            6.7          3.0           5.0          1.7  Iris-versicolor
# 78            5.5          2.4           3.8          1.1  Iris-versicolor
# 73            6.6          3.0           4.4          1.4  Iris-versicolor
# 49            6.4          3.2           4.5          1.5  Iris-versicolor
# 52            6.5          2.8           4.6          1.5  Iris-versicolor
# 71            6.1          2.8           4.7          1.2  Iris-versicolor
# 86            5.6          3.0           4.1          1.3  Iris-versicolor
# 91            5.0          2.3           3.3          1.0  Iris-versicolor
# 140           6.8          3.2           5.9          2.3   Iris-virginica
# 105           7.3          2.9           6.3          1.8   Iris-virginica
# 145           6.2          3.4           5.4          2.3   Iris-virginica
# 127           7.2          3.0           5.8          1.6   Iris-virginica
# 134           6.3          3.4           5.6          2.4   Iris-virginica
# 103           7.6          3.0           6.6          2.1   Iris-virginica
# 101           6.3          2.9           5.6          1.8   Iris-virginica
# 100           7.1          3.0           5.9          2.1   Iris-virginica
# 142           6.7          3.0           5.2          2.3   Iris-virginica
# 139           6.9          3.1           5.1          2.3   Iris-virginica
# 108           6.5          3.2           5.1          2.0   Iris-virginica
# 106           6.7          2.5           5.8          1.8   Iris-virginica
# 120           7.7          2.8           6.7          2.0   Iris-virginica
# 123           7.2          3.2           6.0          1.8   Iris-virginica

# %% [markdown]
# ## K-fold cross-validation

# %% [markdown]
# No estoy seguro de como recibir una función de predicción, entonces va a retornar k tuples, donde el primer conjunto es el entrenamiento, y el segundo los resultados

# %%
def kfold(f, k):
    frame = f.drop_duplicates(ignore_index=True)
    nums = list(range(len(frame.index)))
    shuffle(nums)
    # El ultimo conjunto tendra mas elementos de ser el caso de sobra
    part = []
    div = int((len(frame.index))/k)
    # Particionamos el frame
    for a in range(k-1):
        part.append(frame.iloc[nums[a*div:(a+1)*div]])
    part.append(frame.iloc[nums[(k-1)*div:]])
    # Part tiene las particiones en k
    # Ahora realizamos los tuples
    ret =[]
    for a in range(k):
        ret.append( (pd.concat(part[:a] + part[a+1:]),part[a]) )
    return ret

# %%
res = kfold(union, 3)
for a in res:
    #print("--")
    #print(a[0])
    #print(a[1])
    #print("---")
    print(len(a[0].index), len(a[1].index))
    print(elemComun(a[0], a[1]))
res2 = kfold(union2, 10)
for a in res2:
    print(elemComun(a[0], a[1]))
# Out:
# 98 49
# 98 49 147
# False
# 98 49
# 98 49 147
# False
# 98 49
# 98 49 147
# False
# 4787 531 5318
# False
# 4787 531 5318
# False
# 4787 531 5318
# False
# 4787 531 5318
# False
# 4787 531 5318
# False
# 4787 531 5318
# False
# 4787 531 5318
# False
# 4787 531 5318
# False
# 4787 531 5318
# False
# 4779 539 5318
# False

# %%
def leaveOneOut(f):
    res = []
    frame = f.drop_duplicates(ignore_index=True)
    tam = len(frame.index)
    for a in range(tam):
        r = list(range(tam))
        del r[a]
        res.append( (frame.iloc[r], frame.iloc[a]) )
    return res

# %%
res = leaveOneOut(union)

# %%
for a in res:
    print(a[0])
    print(a[1])
    print("---")
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            5.1
# sepal width             3.5
# petal length            1.4
# petal width             0.2
# class           Iris-setosa
# Name: 0, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            4.9
# sepal width             3.0
# petal length            1.4
# petal width             0.2
# class           Iris-setosa
# Name: 1, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            4.7
# sepal width             3.2
# petal length            1.3
# petal width             0.2
# class           Iris-setosa
# Name: 2, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            4.6
# sepal width             3.1
# petal length            1.5
# petal width             0.2
# class           Iris-setosa
# Name: 3, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            5.0
# sepal width             3.6
# petal length            1.4
# petal width             0.2
# class           Iris-setosa
# Name: 4, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            5.4
# sepal width             3.9
# petal length            1.7
# petal width             0.4
# class           Iris-setosa
# Name: 5, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            4.6
# sepal width             3.4
# petal length            1.4
# petal width             0.3
# class           Iris-setosa
# Name: 6, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            5.0
# sepal width             3.4
# petal length            1.5
# petal width             0.2
# class           Iris-setosa
# Name: 7, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            4.4
# sepal width             2.9
# petal length            1.4
# petal width             0.2
# class           Iris-setosa
# Name: 8, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            4.9
# sepal width             3.1
# petal length            1.5
# petal width             0.1
# class           Iris-setosa
# Name: 9, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            5.4
# sepal width             3.7
# petal length            1.5
# petal width             0.2
# class           Iris-setosa
# Name: 10, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            4.8
# sepal width             3.4
# petal length            1.6
# petal width             0.2
# class           Iris-setosa
# Name: 11, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            4.8
# sepal width             3.0
# petal length            1.4
# petal width             0.1
# class           Iris-setosa
# Name: 12, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            4.3
# sepal width             3.0
# petal length            1.1
# petal width             0.1
# class           Iris-setosa
# Name: 13, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            5.8
# sepal width             4.0
# petal length            1.2
# petal width             0.2
# class           Iris-setosa
# Name: 14, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            5.7
# sepal width             4.4
# petal length            1.5
# petal width             0.4
# class           Iris-setosa
# Name: 15, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            5.4
# sepal width             3.9
# petal length            1.3
# petal width             0.4
# class           Iris-setosa
# Name: 16, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            5.1
# sepal width             3.5
# petal length            1.4
# petal width             0.3
# class           Iris-setosa
# Name: 17, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            5.7
# sepal width             3.8
# petal length            1.7
# petal width             0.3
# class           Iris-setosa
# Name: 18, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            5.1
# sepal width             3.8
# petal length            1.5
# petal width             0.3
# class           Iris-setosa
# Name: 19, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            5.4
# sepal width             3.4
# petal length            1.7
# petal width             0.2
# class           Iris-setosa
# Name: 20, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            5.1
# sepal width             3.7
# petal length            1.5
# petal width             0.4
# class           Iris-setosa
# Name: 21, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            4.6
# sepal width             3.6
# petal length            1.0
# petal width             0.2
# class           Iris-setosa
# Name: 22, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            5.1
# sepal width             3.3
# petal length            1.7
# petal width             0.5
# class           Iris-setosa
# Name: 23, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            4.8
# sepal width             3.4
# petal length            1.9
# petal width             0.2
# class           Iris-setosa
# Name: 24, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            5.0
# sepal width             3.0
# petal length            1.6
# petal width             0.2
# class           Iris-setosa
# Name: 25, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            5.0
# sepal width             3.4
# petal length            1.6
# petal width             0.4
# class           Iris-setosa
# Name: 26, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            5.2
# sepal width             3.5
# petal length            1.5
# petal width             0.2
# class           Iris-setosa
# Name: 27, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            5.2
# sepal width             3.4
# petal length            1.4
# petal width             0.2
# class           Iris-setosa
# Name: 28, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            4.7
# sepal width             3.2
# petal length            1.6
# petal width             0.2
# class           Iris-setosa
# Name: 29, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            4.8
# sepal width             3.1
# petal length            1.6
# petal width             0.2
# class           Iris-setosa
# Name: 30, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            5.4
# sepal width             3.4
# petal length            1.5
# petal width             0.4
# class           Iris-setosa
# Name: 31, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            5.2
# sepal width             4.1
# petal length            1.5
# petal width             0.1
# class           Iris-setosa
# Name: 32, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            5.5
# sepal width             4.2
# petal length            1.4
# petal width             0.2
# class           Iris-setosa
# Name: 33, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            5.0
# sepal width             3.2
# petal length            1.2
# petal width             0.2
# class           Iris-setosa
# Name: 34, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            5.5
# sepal width             3.5
# petal length            1.3
# petal width             0.2
# class           Iris-setosa
# Name: 35, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            4.4
# sepal width             3.0
# petal length            1.3
# petal width             0.2
# class           Iris-setosa
# Name: 36, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            5.1
# sepal width             3.4
# petal length            1.5
# petal width             0.2
# class           Iris-setosa
# Name: 37, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            5.0
# sepal width             3.5
# petal length            1.3
# petal width             0.3
# class           Iris-setosa
# Name: 38, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            4.5
# sepal width             2.3
# petal length            1.3
# petal width             0.3
# class           Iris-setosa
# Name: 39, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            4.4
# sepal width             3.2
# petal length            1.3
# petal width             0.2
# class           Iris-setosa
# Name: 40, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            5.0
# sepal width             3.5
# petal length            1.6
# petal width             0.6
# class           Iris-setosa
# Name: 41, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            5.1
# sepal width             3.8
# petal length            1.9
# petal width             0.4
# class           Iris-setosa
# Name: 42, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length            4.8
# sepal width             3.0
# petal length            1.4
# petal width             0.3
# class           Iris-setosa
# Name: 43, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ...
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length               6.1
# sepal width                2.6
# petal length               5.6
# petal width                1.4
# class           Iris-virginica
# Name: 132, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length               7.7
# sepal width                3.0
# petal length               6.1
# petal width                2.3
# class           Iris-virginica
# Name: 133, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length               6.3
# sepal width                3.4
# petal length               5.6
# petal width                2.4
# class           Iris-virginica
# Name: 134, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length               6.4
# sepal width                3.1
# petal length               5.5
# petal width                1.8
# class           Iris-virginica
# Name: 135, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length               6.0
# sepal width                3.0
# petal length               4.8
# petal width                1.8
# class           Iris-virginica
# Name: 136, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length               6.9
# sepal width                3.1
# petal length               5.4
# petal width                2.1
# class           Iris-virginica
# Name: 137, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length               6.7
# sepal width                3.1
# petal length               5.6
# petal width                2.4
# class           Iris-virginica
# Name: 138, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length               6.9
# sepal width                3.1
# petal length               5.1
# petal width                2.3
# class           Iris-virginica
# Name: 139, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length               6.8
# sepal width                3.2
# petal length               5.9
# petal width                2.3
# class           Iris-virginica
# Name: 140, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length               6.7
# sepal width                3.3
# petal length               5.7
# petal width                2.5
# class           Iris-virginica
# Name: 141, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 141           6.7          3.3           5.7          2.5  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length               6.7
# sepal width                3.0
# petal length               5.2
# petal width                2.3
# class           Iris-virginica
# Name: 142, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 141           6.7          3.3           5.7          2.5  Iris-virginica
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length               6.3
# sepal width                2.5
# petal length               5.0
# petal width                1.9
# class           Iris-virginica
# Name: 143, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 141           6.7          3.3           5.7          2.5  Iris-virginica
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length               6.5
# sepal width                3.0
# petal length               5.2
# petal width                2.0
# class           Iris-virginica
# Name: 144, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 141           6.7          3.3           5.7          2.5  Iris-virginica
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 146           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length               6.2
# sepal width                3.4
# petal length               5.4
# petal width                2.3
# class           Iris-virginica
# Name: 145, dtype: object
# ---
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 141           6.7          3.3           5.7          2.5  Iris-virginica
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# 144           6.5          3.0           5.2          2.0  Iris-virginica
# 145           6.2          3.4           5.4          2.3  Iris-virginica
#
# [146 rows x 5 columns]
# sepal length               5.9
# sepal width                3.0
# petal length               5.1
# petal width                1.8
# class           Iris-virginica
# Name: 146, dtype: object
# ---

# %% [markdown]
# ## Algoritmos de aprendizaje

# %% [markdown]
# ### knn

# %%
def contieneNull(a):
    return (a.isnull().values.any())

def knnClass(data, fila, k):
    d = data.reset_index()
    l = list(d.columns.values)[1:-1] # Excluye el ultimo columna
    df = pd.DataFrame()
    df['acum'] = [0]*len(d)
    for a in l:
        df['acum'] = (d[a]-fila[a])*(d[a]-fila[a])
    df['acum'] = np.sqrt(df['acum'])
    menores = df['acum'].nsmallest(k)
    etiquetas = d[list(d.columns.values)[-1]]
    votos = pd.merge(menores,etiquetas,left_index=True,right_index=True)
    votos = votos[list(votos.columns.values)[-1]]
    return votos.mode().iloc[0]

# %%
knnClass(union, union.iloc[140], 20)
# Out:
# 'Iris-virginica'

# %% [markdown]
# ## Accuracy y matriz de confusion

# %%
def obtenerValores(pares, e):
    tp = 0 # true negative
    fn = 0 # false negative
    fp = 0 # false positive
    tn = 0 # true negative
    for a in pares:
        if a[0]==e:
            # Realmente es positivo
            if a[1]==e:
                tp+=1
            else:
                fn+=1
        else:
             if a[1]==e:
                 fp+=1
             else:
                 tn+=1
    return [tp,fn,fp,tn]

def obtenerAccuracy(pares,e):
    tp,fn,fp,tn=obtenerValores(pares,e)
    return (tp+tn)/(tp+tn+fp+fn)

def matEsp(pares, e): # Realiza el matriz y el accuracy sobre un solo valor
    tp,fn,fp,tn=obtenerValores(pares,e)
    print(f"Elaborado sobre {e}")
    print(f"Accuracy: {(tp+tn)/(tp+tn+fp+fn)}")
    print("\t1\t0")
    print(f"1\t{tp}\t{fn}")
    print(f"0\t{fp}\t{tn}")

def obtenerAccGlobal(pares):
    s = set()
    for a in pares:
        s.add(a[0])
    prom = []
    for a in s:
        prom.append(obtenerAccuracy(pares,a))
    return sum(prom)/len(prom)

    
def accYMat(pares): # Sobre los pares de (real,prediccion), se obtiene el accuracy y el matriz de confusion
    s = set()
    for a in pares:
        s.add(a[0])
    print("Arriba es la clase predicha, a la izquierda es la clase real.")
    prom = []
    for a in s:
        prom.append(obtenerAccuracy(pares,a))
    print(f"Accuracy global: {sum(prom)/len(prom)}")
    print("<---")
    for a in s:
        matEsp(pares,a)
    print("--->")

# %% [markdown]
# ### Implementación de algoritmos de aprendizaje con algoritmos de validación

# %%
def knnHoldOut(data,k):
    ent,val = holdOut(data, 0.3)
    # Calculamos un vector de distancia
    real = []
    pred = []
    for a in range(len(val)):
        real.append(val.iloc[a][val.columns[-1]])
        pred.append(knnClass(ent, val.iloc[a],k))
    return list(zip(real,pred))
def knnKFold(data,x):
    k = kfold(data, 10)
    #ent,val = holdOut(data, 0.3)
    # Calculamos un vector de distancia
    real = []
    pred = []
    for b in k:
        ent,val = b
        for a in range(len(val)):
            real.append(val.iloc[a][val.columns[-1]])
            pred.append(knnClass(ent, val.iloc[a],x))
    return list(zip(real,pred))
def knnOneOut(f,k):
    # res = []
    real = []
    pred = []

    frame = f.drop_duplicates(ignore_index=True)
    tam = len(frame.index)
    for a in range(tam):
        r = list(range(tam))
        del r[a]
        ent = frame.iloc[r]
        val = frame.iloc[a]
        real.append(val[ent.columns[-1]])
        pred.append(knnClass(ent, val, k))
    return list(zip(real,pred))

# %% [markdown]
# ## Validación

# %% [markdown]
# Primeramente obtenermos el valor de k, mediante la siguiente prueba. Vamos a correr los métodos de validación para diferentes valroes de k, y registrar que valor se obtuvo.

# %%
import matplotlib.pyplot

# %%
r = range(1,20)
res = []
for a in r:
    res.append(obtenerAccGlobal(knnOneOut(union, a)))

# %%
matplotlib.pyplot.plot(r,res)

# %% [markdown]
# ### knn

# %%
k = 5

# %% [markdown]
# ## Iris

# %%
kholi = knnHoldOut(union,k)
kfoli = knnKFold(union,k)
konei = knnOneOut(union, k)

# %%
accYMat(kholi)
accYMat(kfoli)
accYMat(konei)
# Out:
# Arriba es la clase predicha, a la izquierda es la clase real.
# Accuracy global: 0.9523809523809524
# <---
# Elaborado sobre Iris-virginica
# Accuracy: 0.9285714285714286
# 	1	0
# 1	12	2
# 0	1	27
# Elaborado sobre Iris-versicolor
# Accuracy: 0.9285714285714286
# 	1	0
# 1	13	1
# 0	2	26
# Elaborado sobre Iris-setosa
# Accuracy: 1.0
# 	1	0
# 1	14	0
# 0	0	28
# --->
# Arriba es la clase predicha, a la izquierda es la clase real.
# Accuracy global: 0.9682539682539683
# <---
# Elaborado sobre Iris-virginica
# Accuracy: 0.9523809523809523
# 	1	0
# 1	44	5
# 0	2	96
# Elaborado sobre Iris-versicolor
# Accuracy: 0.9523809523809523
# 	1	0
# 1	48	2
# 0	5	92
# Elaborado sobre Iris-setosa
# Accuracy: 1.0
# 	1	0
# 1	48	0
# 0	0	99
# --->
# Arriba es la clase predicha, a la izquierda es la clase real.
# Accuracy global: 0.9727891156462585
# <---
# Elaborado sobre Iris-virginica
# Accuracy: 0.9591836734693877
# 	1	0
# 1	44	5
# 0	1	97
# Elaborado sobre Iris-versicolor
# Accuracy: 0.9591836734693877
# 	1	0
# 1	49	1
# 0	5	92
# Elaborado sobre Iris-setosa
# Accuracy: 1.0
# 	1	0
# 1	48	0
# 0	0	99
# --->

# %% [markdown]
# ## Vino

# %%
kholv = knnHoldOut(union2,k)
kfolv = knnKFold(union2,k)
konev = knnOneOut(union2, k)

# %%
accYMat(kholv)
accYMat(kfolv)
accYMat(konev)
# Out:
# Arriba es la clase predicha, a la izquierda es la clase real.
# Accuracy global: 0.8218550776690312
# <---
# Elaborado sobre 3.0
# Accuracy: 0.994343180389692
# 	1	0
# 1	0	8
# 0	1	1582
# Elaborado sobre 4.0
# Accuracy: 0.961659333752357
# 	1	0
# 1	0	61
# 0	0	1530
# Elaborado sobre 5.0
# Accuracy: 0.44123192960402263
# 	1	0
# 1	511	14
# 0	875	191
# Elaborado sobre 6.0
# Accuracy: 0.5443117536140792
# 	1	0
# 1	82	614
# 0	111	784
# Elaborado sobre 7.0
# Accuracy: 0.8397234443746072
# 	1	0
# 1	6	250
# 0	5	1330
# Elaborado sobre 8.0
# Accuracy: 0.9723444374607165
# 	1	0
# 1	0	44
# 0	0	1547
# Elaborado sobre 9.0
# Accuracy: 0.9993714644877436
# 	1	0
# 1	0	1
# 0	0	1590
# --->
# Arriba es la clase predicha, a la izquierda es la clase real.
# Accuracy global: 0.8452157094503842
# <---
# Elaborado sobre 3.0
# Accuracy: 0.9937946596464836
# 	1	0
# 1	1	29
# 0	4	5284
# Elaborado sobre 4.0
# Accuracy: 0.9588191049266641
# 	1	0
# 1	0	206
# 0	13	5099
# Elaborado sobre 5.0
# Accuracy: 0.6615268898081986
# 	1	0
# 1	1021	730
# 0	1070	2497
# Elaborado sobre 6.0
# Accuracy: 0.5340353516359534
# 	1	0
# 1	1257	1066
# 0	1412	1583
# Elaborado sobre 7.0
# Accuracy: 0.7986084994358782
# 	1	0
# 1	158	697
# 0	374	4089
# Elaborado sobre 8.0
# Accuracy: 0.9706656637833773
# 	1	0
# 1	0	148
# 0	8	5162
# Elaborado sobre 9.0
# Accuracy: 0.9990597969161339
# 	1	0
# 1	0	5
# 0	0	5313
# --->
# Arriba es la clase predicha, a la izquierda es la clase real.
# Accuracy global: 0.8374254553269221
# <---
# Elaborado sobre 3.0
# Accuracy: 0.9936066190297104
# 	1	0
# 1	0	30
# 0	4	5284
# Elaborado sobre 4.0
# Accuracy: 0.9396389620157954
# 	1	0
# 1	10	196
# 0	125	4987
# Elaborado sobre 5.0
# Accuracy: 0.604550582925912
# 	1	0
# 1	1215	536
# 0	1567	2000
# Elaborado sobre 6.0
# Accuracy: 0.5443775855584806
# 	1	0
# 1	878	1445
# 0	978	2017
# Elaborado sobre 7.0
# Accuracy: 0.8113952613764573
# 	1	0
# 1	188	667
# 0	336	4127
# Elaborado sobre 8.0
# Accuracy: 0.9693493794659647
# 	1	0
# 1	1	147
# 0	16	5154
# Elaborado sobre 9.0
# Accuracy: 0.9990597969161339
# 	1	0
# 1	0	5
# 0	0	5313
# --->

# %% [markdown]
# ## Abalone

# %%
khola = knnHoldOut(union3,k)
kfola = knnKFold(union3,k)
konea = knnOneOut(union3, k)

# %%
accYMat(khola)
accYMat(kfola)
accYMat(konea)
# Out:
# Arriba es la clase predicha, a la izquierda es la clase real.
# Accuracy global: 0.9266805587713206
# <---
# Elaborado sobre 3.0
# Accuracy: 0.9967585089141004
# 	1	0
# 1	0	4
# 0	0	1230
# Elaborado sobre 4.0
# Accuracy: 0.9846029173419774
# 	1	0
# 1	7	9
# 0	10	1208
# Elaborado sobre 5.0
# Accuracy: 0.9611021069692058
# 	1	0
# 1	15	19
# 0	29	1171
# Elaborado sobre 6.0
# Accuracy: 0.9230145867098866
# 	1	0
# 1	16	61
# 0	34	1123
# Elaborado sobre 7.0
# Accuracy: 0.7763371150729336
# 	1	0
# 1	71	46
# 0	230	887
# Elaborado sobre 8.0
# Accuracy: 0.8435980551053485
# 	1	0
# 1	14	156
# 0	37	1027
# Elaborado sobre 9.0
# Accuracy: 0.6474878444084279
# 	1	0
# 1	104	102
# 0	333	695
# Elaborado sobre 10.0
# Accuracy: 0.7536466774716369
# 	1	0
# 1	37	152
# 0	152	893
# Elaborado sobre 11.0
# Accuracy: 0.859805510534846
# 	1	0
# 1	17	128
# 0	45	1044
# Elaborado sobre 12.0
# Accuracy: 0.9254457050243112
# 	1	0
# 1	1	78
# 0	14	1141
# Elaborado sobre 13.0
# Accuracy: 0.9505672609400324
# 	1	0
# 1	0	60
# 0	1	1173
# Elaborado sobre 14.0
# Accuracy: 0.9627228525121556
# 	1	0
# 1	0	37
# 0	9	1188
# Elaborado sobre 15.0
# Accuracy: 0.9376012965964343
# 	1	0
# 1	2	28
# 0	49	1155
# Elaborado sobre 16.0
# Accuracy: 0.9789303079416531
# 	1	0
# 1	0	19
# 0	7	1208
# Elaborado sobre 17.0
# Accuracy: 0.986223662884927
# 	1	0
# 1	0	17
# 0	0	1217
# Elaborado sobre 18.0
# Accuracy: 0.9902755267423015
# 	1	0
# 1	0	12
# 0	0	1222
# Elaborado sobre 19.0
# Accuracy: 0.9927066450567261
# 	1	0
# 1	0	9
# 0	0	1225
# Elaborado sobre 20.0
# Accuracy: 0.9943273905996759
# 	1	0
# 1	0	7
# 0	0	1227
# Elaborado sobre 21.0
# Accuracy: 0.9975688816855753
# 	1	0
# 1	0	3
# 0	0	1231
# Elaborado sobre 22.0
# Accuracy: 0.9991896272285251
# 	1	0
# 1	0	1
# 0	0	1233
# Elaborado sobre 23.0
# Accuracy: 0.9983792544570502
# 	1	0
# 1	0	2
# 0	0	1232
# --->
# Arriba es la clase predicha, a la izquierda es la clase real.
# Accuracy global: 0.9438763295598344
# <---
# Elaborado sobre 1.0
# Accuracy: 0.9997605937275557
# 	1	0
# 1	0	1
# 0	0	4176
# Elaborado sobre 2.0
# Accuracy: 0.9997605937275557
# 	1	0
# 1	0	1
# 0	0	4176
# Elaborado sobre 3.0
# Accuracy: 0.9947330620062246
# 	1	0
# 1	1	14
# 0	8	4154
# Elaborado sobre 4.0
# Accuracy: 0.9806080919320086
# 	1	0
# 1	21	36
# 0	45	4075
# Elaborado sobre 5.0
# Accuracy: 0.9502034953315777
# 	1	0
# 1	33	82
# 0	126	3936
# Elaborado sobre 6.0
# Accuracy: 0.9087862101987072
# 	1	0
# 1	81	178
# 0	203	3715
# Elaborado sobre 7.0
# Accuracy: 0.8237969834809672
# 	1	0
# 1	140	251
# 0	485	3301
# Elaborado sobre 8.0
# Accuracy: 0.7433564759396696
# 	1	0
# 1	175	393
# 0	679	2930
# Elaborado sobre 9.0
# Accuracy: 0.7467081637538904
# 	1	0
# 1	174	515
# 0	543	2945
# Elaborado sobre 10.0
# Accuracy: 0.7759157289920996
# 	1	0
# 1	130	504
# 0	432	3111
# Elaborado sobre 11.0
# Accuracy: 0.8302609528369643
# 	1	0
# 1	91	396
# 0	313	3377
# Elaborado sobre 12.0
# Accuracy: 0.8989705530284894
# 	1	0
# 1	20	247
# 0	175	3735
# Elaborado sobre 13.0
# Accuracy: 0.9262628680871439
# 	1	0
# 1	19	184
# 0	124	3850
# Elaborado sobre 14.0
# Accuracy: 0.9571462772324635
# 	1	0
# 1	4	122
# 0	57	3994
# Elaborado sobre 15.0
# Accuracy: 0.9700742159444578
# 	1	0
# 1	1	102
# 0	23	4051
# Elaborado sobre 16.0
# Accuracy: 0.9791716542973425
# 	1	0
# 1	3	64
# 0	23	4087
# Elaborado sobre 17.0
# Accuracy: 0.9784534354800096
# 	1	0
# 1	2	56
# 0	34	4085
# Elaborado sobre 18.0
# Accuracy: 0.9899449365573378
# 	1	0
# 1	0	42
# 0	0	4135
# Elaborado sobre 19.0
# Accuracy: 0.9923389992817812
# 	1	0
# 1	0	32
# 0	0	4145
# Elaborado sobre 20.0
# Accuracy: 0.9911419679195594
# 	1	0
# 1	0	26
# 0	11	4140
# Elaborado sobre 21.0
# Accuracy: 0.996408905913335
# 	1	0
# 1	0	14
# 0	1	4162
# Elaborado sobre 22.0
# Accuracy: 0.998563562365334
# 	1	0
# 1	0	6
# 0	0	4171
# Elaborado sobre 23.0
# Accuracy: 0.9978453435480009
# 	1	0
# 1	0	9
# 0	0	4168
# Elaborado sobre 24.0
# Accuracy: 0.9995211874551113
# 	1	0
# 1	0	2
# 0	0	4175
# Elaborado sobre 25.0
# Accuracy: 0.9997605937275557
# 	1	0
# 1	0	1
# 0	0	4176
# Elaborado sobre 26.0
# Accuracy: 0.9997605937275557
# 	1	0
# 1	0	1
# 0	0	4176
# Elaborado sobre 27.0
# Accuracy: 0.9995211874551113
# 	1	0
# 1	0	2
# 0	0	4175
# Elaborado sobre 29.0
# Accuracy: 0.9997605937275557
# 	1	0
# 1	0	1
# 0	0	4176
# --->
# Arriba es la clase predicha, a la izquierda es la clase real.
# Accuracy global: 0.9438079277677075
# <---
# Elaborado sobre 1.0
# Accuracy: 0.9997605937275557
# 	1	0
# 1	0	1
# 0	0	4176
# Elaborado sobre 2.0
# Accuracy: 0.9997605937275557
# 	1	0
# 1	0	1
# 0	0	4176
# Elaborado sobre 3.0
# Accuracy: 0.9935360306440029
# 	1	0
# 1	4	11
# 0	16	4146
# Elaborado sobre 4.0
# Accuracy: 0.9849174048360066
# 	1	0
# 1	25	32
# 0	31	4089
# Elaborado sobre 5.0
# Accuracy: 0.9631314340435719
# 	1	0
# 1	52	63
# 0	91	3971
# Elaborado sobre 6.0
# Accuracy: 0.9071103662915968
# 	1	0
# 1	77	182
# 0	206	3712
# Elaborado sobre 7.0
# Accuracy: 0.8589897055302849
# 	1	0
# 1	139	252
# 0	337	3449
# Elaborado sobre 8.0
# Accuracy: 0.7950682307876467
# 	1	0
# 1	129	439
# 0	417	3192
# Elaborado sobre 9.0
# Accuracy: 0.7371319128561168
# 	1	0
# 1	176	513
# 0	585	2903
# Elaborado sobre 10.0
# Accuracy: 0.730907349772564
# 	1	0
# 1	164	470
# 0	654	2889
# Elaborado sobre 11.0
# Accuracy: 0.8352884845582954
# 	1	0
# 1	74	413
# 0	275	3415
# Elaborado sobre 12.0
# Accuracy: 0.883887957864496
# 	1	0
# 1	19	248
# 0	237	3673
# Elaborado sobre 13.0
# Accuracy: 0.911419679195595
# 	1	0
# 1	24	179
# 0	191	3783
# Elaborado sobre 14.0
# Accuracy: 0.9454153698826909
# 	1	0
# 1	5	121
# 0	107	3944
# Elaborado sobre 15.0
# Accuracy: 0.9619344026813502
# 	1	0
# 1	2	101
# 0	58	4016
# Elaborado sobre 16.0
# Accuracy: 0.9698348096720134
# 	1	0
# 1	1	66
# 0	60	4050
# Elaborado sobre 17.0
# Accuracy: 0.9846779985635624
# 	1	0
# 1	0	58
# 0	6	4113
# Elaborado sobre 18.0
# Accuracy: 0.9894661240124492
# 	1	0
# 1	0	42
# 0	2	4133
# Elaborado sobre 19.0
# Accuracy: 0.9923389992817812
# 	1	0
# 1	0	32
# 0	0	4145
# Elaborado sobre 20.0
# Accuracy: 0.9918601867368925
# 	1	0
# 1	0	26
# 0	8	4143
# Elaborado sobre 21.0
# Accuracy: 0.9954512808235576
# 	1	0
# 1	0	14
# 0	5	4158
# Elaborado sobre 22.0
# Accuracy: 0.998563562365334
# 	1	0
# 1	0	6
# 0	0	4171
# Elaborado sobre 23.0
# Accuracy: 0.9978453435480009
# 	1	0
# 1	0	9
# 0	0	4168
# Elaborado sobre 24.0
# Accuracy: 0.9995211874551113
# 	1	0
# 1	0	2
# 0	0	4175
# Elaborado sobre 25.0
# Accuracy: 0.9997605937275557
# 	1	0
# 1	0	1
# 0	0	4176
# Elaborado sobre 26.0
# Accuracy: 0.9997605937275557
# 	1	0
# 1	0	1
# 0	0	4176
# Elaborado sobre 27.0
# Accuracy: 0.9995211874551113
# 	1	0
# 1	0	2
# 0	0	4175
# Elaborado sobre 29.0
# Accuracy: 0.9997605937275557
# 	1	0
# 1	0	1
# 0	0	4176
# --->
