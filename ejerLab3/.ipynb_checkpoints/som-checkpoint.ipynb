# %%
import pandas as pd
import numpy as np
import sklearn as sk
import sklearn.datasets as dt
import matplotlib.pyplot as mp
from ucimlrepo import fetch_ucirepo
import minisom

# %%
wine_quality = fetch_ucirepo(id=186)
X = wine_quality.data.features 
y = wine_quality.data.targets

data = pd.DataFrame.to_numpy(X) # Convertimos a np

som = MiniSom(20, 20, 11, sigma=0.3, learning_rate=0.5) # Inizializamos el som de 20x20, de 11 dimensiones de la calidad del vino
som.train(data, 100) # Realizamos 100 iteraciones

# %%
plt.figure(figsize=(7, 7))
plt.pcolor(som.distance_map().T, cmap='bone_r')
plt.colorbar()
