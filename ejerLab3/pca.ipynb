# %%
import pandas as pd
import sklearn as sk
import sklearn.datasets as dt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as mp

# %%
 testData = dt.load_diabetes(as_frame=True)
# testData

# %%
(val,y) = dt.load_diabetes(return_X_y=True, as_frame=True)
features = dt.load_diabetes().feature_names

# %%
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['pc1', 'pc2'])
finalDf = pd.concat([principalDf, y], axis = 1)
print(finalDf)
# Out:
#           pc1       pc2  target
# 0    0.587199 -1.946832   151.0
# 1   -2.831625  1.372082    75.0
# 2    0.272129 -1.634901   141.0
# 3    0.049281  0.382278   206.0
# 4   -0.756421  0.811960   135.0
# ..        ...       ...     ...
# 437  1.239525 -1.035968   178.0
# 438  1.264719  0.761319   104.0
# 439 -0.205206 -1.205487   132.0
# 440  0.692871  0.210127   220.0
# 441 -1.903941  3.975777    57.0
#
# [442 rows x 3 columns]

# %%
fig = mp.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
# ax.scatter(finalDf['pc1'], finalDf['pc2'])

Max = max(finalDf['target'])
Min = min(finalDf['target'])
m = (1-0.5)/(Max-Min)
b = 0.5 - m*Min

colrs = list(map(lambda x: [0,m*x+b,0], finalDf['target']))
ax.scatter(finalDf['pc1'],finalDf['pc2'],c=colrs)

#for a,b,c in zip(finalDf['pc1'],finalDf['pc2'],finalDf['target']):
    # print(a,b,int(m*c + b))
 #   ax.scatter(a,b,color=)
